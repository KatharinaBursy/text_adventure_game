# %%
"""
Created on Sun Oct 17 14:50:38 2021

@author: Katharina Sabrina bursy
"""

"""
    DocString:
    
    A) Introduction:
    This game is based on the movie Indiana Jones, as well as the egyptian mythology
    book I am currently reading. It does not strictly follow the movie's storyline
    since I enhanced it with my ideas.
    It consists of three stages, and also has defined functions for start, win, 
    and lose. This game requires honesty, altruism and a
    small amount of knowledge from egyptian mythology will be helpful.
    
    Round 1: Decide which path to take
    Round 2: Take golden ball or not
    Round 3: Defeat the bloodthirsty mummies

    
    B) Known Bugs and/or Errors:
    None.
    
"""

import time
import random

def intro():
#intro def
#print statements to introduce the game to the player
    print(f"""
No one ever got close to finding the eternity stone, but you are the first one
who managed to encode your late grandfather's map guiding to Hathor's temple. 
         """)
    
    time.sleep(1)  
    #time.sleep makes the text appear after a couple of seconds
    
    print(f"""
You follow the map till you end up in front of the huge golden temple entrance
with lion status on the side. 
         """)
    input(prompt= "<Press any key to continue>\n") 
    #input option so that user needs to press any key to continue to next stage
    #transition to next stage
    stage_1()    

  
def stage_1():
#simple print statements that display the text till it is time to choose an option    
    print(f"""
You walk into the temple and descend the stairs into the darkness. You grab your
flashlight and continue till the stairs lead into a bigger room .
         """)    
    
    time.sleep(1)
    #time.sleep makes the text appear after a couple of seconds
    
    print(f"""
As you step into it, torches light up and reveal three tunnels. 
         """)
    input(prompt= "<Press any key to continue>\n")
    #input option so that user needs to press any key to continue to next stage
    #transition to next stage
    stage_1_options()

    
def stage_1_options():
    #create random variable that will the right path, between 1 and 3 the path options
    #additional random element
    right_path= random.randint(1, 3)
    #right_path 
    #print the element for testing purposes
    
    def generating_path(right_path):
    #function in function since I was not able not use a global varibale and I
    #did not find a better way to achieve the outcome
    #randomly correct generated path created in first function and taken as 
    #argument for the next one
    #function in function so that player gets to get the option of chosing again
    #in case that he went wrong
        #print(right_path)
        #print the element for testing purposes
        
        
        #print options to the player
        print(f"""
Traveller , which path would you like to choose?
1) The left path - with lion paintings
2) The middle path - with cobra paintings
3) The right path - with falcon paintings
                 """) 
        
        choice_1= input(prompt= "What path are you taking? ").casefold() 
        #user input plus casefold
        
        if "1" in choice_1 or  "one" in choice_1 or  "left" in choice_1 or\
        "lion" in choice_1 or "the left path" in choice_1:
            #check if the input matches the answer possibilities given for one
            if right_path== 1:
                #if the randomly correct stage is 1 continue the game
                #print("right stage")
                #above for testing purposes
                stage_1_right()
                #transition to correct stage
            else:
                #the wrong stage was another def before but this is not possible
                #anymore because of the nested functions, therefore it is in the
                #funtion itself
                print(f"""
It has to be this path, right?
                        """)    
                time.sleep(1)
#make text disappear later
                print(f"""
You follow the path till you see that this is a dead end.
                    """)  
                time.sleep(1) 
                print(f"""
You take some more steps, when the tile in the floor you just stepped on clicks.
                      """)  
                time.sleep(1)      
                print(f"""
The floor beneath you moves away and you fall. You are again at the intersection. 
                             """)
                input(prompt= "<Press any key to continue>\n")
                #let user press any key so that he can continue to the next stage
                #since player was walking in a circle, replay the options for this stage/
                #so that he can try another path
                generating_path(right_path)
                #transition to correct stage      

        elif "2" in choice_1 or "two" in choice_1 or  "middle" in choice_1 or \
         "cobra" in choice_1 or "the middle path" in choice_1:
         #check if the input matches the answer possibilities given for two   
            
            if right_path== 2:
                #print("right stage")
                #above for testing purposes
                #if the randomly correct stage is 2 continue the game
                stage_1_right()
                #transition to correct stage 
                
            else:
                #the wrong stage was another def before but this is not possible
                #anymore because of the nested functions, therefore it is in the
                #funtion itself
                print(f"""
It has to be this path, right?
                        """)    
                time.sleep(1)
                #make text disappear later
                print(f"""
You follow the path till you see that this is a dead end.
                    """)  
                time.sleep(1) 
                print(f"""
You take some more steps, when the tile in the floor you just stepped on clicks.
                      """)  
                time.sleep(1)      
                print(f"""
The floor beneath you moves away and you fall. You are again at the intersection. 
                             """)
                input(prompt= "<Press any key to continue>\n")
                #let user press any key so that he can continue to the next stage
                #since player was walking in a circle, replay the options for this stage/
                #so that he can try another path
                generating_path(right_path)
                #transition to correct stage 
                
        elif "3" in choice_1 or "three" in choice_1 or "falcon" in choice_1 or\
         "the right path" in choice_1:
             #check if the input matches the answer possibilities given for three
            if right_path== 3:
                #print("right stage")
                #above for testing purposes
                #if the randomly correct stage is 2 continue the game
                stage_1_right()
            else:
                #the wrong stage was another def before but this is not possible
                #anymore because of the nested functions, therefore it is in the
                #funtion itself
                print(f"""
It has to be this path, right?
                        """)    
                time.sleep(1)
                #make text disappear later
                print(f"""
You follow the path till you see that this is a dead end.
                    """)  
                time.sleep(1) 
                print(f"""
You take some more steps, when the tile in the floor you just stepped on clicks.
                      """)  
                time.sleep(1)      
                print(f"""
The floor beneath you moves away and you fall. You are again at the intersection. 
                             """)
                input(prompt= "<Press any key to continue>\n")
                #let user press any key so that he can continue to the next stage
                #since player was walking in a circle, replay the options for this stage/
                #so that he can try another path
                generating_path(right_path)
                #transition to correct stage 
                
    generating_path(right_path)
    #call after the function stage_1_options function so that i gets read and
    #the nested function works
    
    
def stage_1_right():
    #function for the right stage that continues afterwards with stage 2
    #simple print statements that display the text
    print(f"""
You decide that the correct path has to be the this one. You are sure. 
         """)    
    time.sleep(1)
    print(f"""
You follow the path till you see some light at the end of tunnel.
         """)    
    time.sleep(1)
    print(f"""
You run towards the end and see that there is a huge room waiting for you to explore.
         """)    
    input(prompt= "<Press any key to continue>\n")
    #user has to press a key to get towards the next stage 
    stage_2()
    #transition to stage 2

              
def stage_2():
    #function for Intro to stage 2
    #simple print statements that display the text
    
    print(f"""
In the middle of the room is a platform that showcases a golden ball with a red
gemstone. 
         """)    
    time.sleep(1)
    #make text disappear later
    print(f"""
Could this be the eternity stone? You can’t believe that the legend is true.  
         """)    
    time.sleep(1)  
    print(f"""
You look around and realize that the room is filled with many other valuables. 
         """)    
    
    time.sleep(2)
    stage_2_options()
    #transition to the option for this stage

def stage_2_options(): 
    #function for the options in stage 2
    #print the options for te player so that he can choose
    print(f"""
Traveller , what do you want to do?
1) Search the room and leave the golden ball
2) Take the ball but replace it with a stone shaped like a lion head
3) Take the ball but replace it with a golden statue shaped like a cobra
         """)    
     
    #input plus casefold for the accepted answer choices list    
    choice_2= input(prompt= "What will it be ? ").casefold()
    
    #check if the user inputted an adequate answer and then play the belonging sequence
    if "1" in  choice_2 or "one" in  choice_2 or "search" in choice_2 or\
    "search the room" in choice_2 or "leave the golden ball" in choice_2:
        stage_2_right()
        #transition to the right stage
    

    elif "2" in  choice_2 or "two" in choice_2 or "lion head" in choice_2 or\
    "take ball and replace with stone shaped lion head" in choice_2:
        stage_2_wrong_1()
        #transition to the wrong stage
        
    elif "3" in  choice_2 or "three" in choice_2 or "cobra statue" in choice_2 or\
    "take ball and replace with cobra statue" in choice_2:
        stage_2_wrong_2()
        #transition to the wrong stage
        
    else:
        #statement in case the user inputs something unexpected
        #show user that the answer was unexpected
        print("This is not a valid answer. Try again!")
        #transition to the next stage
        #in this case ask again for adequate input
        stage_2_options()

def stage_2_wrong_1():
    #function for the first wrong path in stage 2
    #this is theoretically a wrong stage, put the player still survives last minute
    #therefore at the end transition to stage 3
    #simpel print statements for the text with transition to next stage
    print(f"""
You replace the golden ball with the stone, when water starts pouring into the 
room from the ceiling. 
         """)    
    time.sleep(1)
    print(f"""
The water is quickly rising when you realize there is a opening with a shape of 
a lion next to it on the ceiling.
         """)  
    time.sleep(1)
    print(f"""
When you are finally able to reach the ceiling, you stick the lion in the lion 
shaped hole and wait. 
         """)
    time.sleep(1)      
    print(f"""
A second before the room is completely filled with water the hole opens and you
can safely climb out of it. 
         """)
    input(prompt="<Press any key to continue>\n")
    #user needs to click on any key to transition to the next stage          
    stage_3()
    #transition to third stage
   
    
def stage_2_wrong_2():
    #wrong stage in which the player can die, when chosen
    print(f"""
You replace the golden ball with the statue, when suddenly your entrance and exit
get blocked. 
         """)    
    time.sleep(1)
    print(f"""
You realize that the walls start slowly moving in and you might get squished to death. 
         """)    
    time.sleep(1)
    print(f"""
The walls start carving in and you hold onto the stone and hope that this is 
the eternity stone that will protect you.  
         """)
    input(prompt= "<Press any key to continue>\n")
    #user needs to press any key to continue
    death()
    #player dies, going over to death sequence
   
def stage_2_right():
    #correct stage for surving the game
    #hint dropped here for stage 3
    print(f"""
You believe that this can't be the eternity stone and that there is something 
more valuable to find here. 
         """)
    time.sleep(1)
    print(f"""
You rummage through some drawers and find an old book, a manual for the eternity
stone.
         """)    
    time.sleep(1)
    print(f"""
Your chances are better fighting only mid level evil. You gather 
all your things and make you way further into the temple.
         """)  
    #little hint given here for the last stage
    #further explained in stage 3
    stage_3()
    #transition to stage 3


def stage_3():
    #funtion for the intro of stage 3
    #simple print statement to display text till options
    print(f"""
You walked for a while till you end up in front of the entrance to Hathor's chamber. 
        """) 
    time.sleep(1)
    print(f"""
You enter the room and find more treasures than you could have imagined with
Hathor\'s grave in the middle with a blue stone on top of it. 
         """)    
    time.sleep(1)
    print(f"""
“Traveller, you found the eternity stone! Now it shall belong to you.” 
        """)    
    
    time.sleep(1)

    print(f"""
You are so immersed in the room that you only now realize that the door is closed
and there is a scratching sound outside of it. 
“Evil came upon you! You have to fight it if you want to survive!"”
  """)    
    input(prompt="<Press any key to continue>\n")
    #as usual the player needs to press any key to continue
    #Transition to the correct stage
    stage_3_options()
    
    
  
def stage_3_options():
    #display the options for player
    print(f"""
Traveller, how do you fight the evil?
1. The eternity stone obviously
2. Fire - monsters don't like fire
3. With your fancy karate skills
             """)
    
    #input so that user can input choice
    #casefold for checking the answer
    choice_3= input(prompt= "Decide now!  ").casefold()
    
     # check if the choice given by player is adequate and see what option he chose      
    if "1" in choice_3 or "one" in choice_3 or "eternity stone" in choice_3 or\
    "obviously" in choice_3:
        #random varibale to spice up the age of the mummies
        mum_age= random.randint(2000,5000)
        
        print(f"""
Obviously you gonna use the eternity stone to fight the evil. Did you find the 
clue that will help you fight the battle? Outside the door is a bunch of {mum_age} 
year old mummies that are trying to kill you.
     """)  
        stage_3_right()
        #transition to the right stage in which player gets a chnce to survive

    elif "2" in choice_3 or "two" in choice_3 or "fire" in choice_3 or\
    "don\'t like fire" in choice_3 :
        stage_3_wrong_1()
    

    elif "3" in choice_3 or "three" in choice_3 or "karate" in choice_3\
    or "fancy skills" in choice_3:
        stage_3_wrong_2()
    
    
    else:
        print("Invalid choice. Try again.")
        #display that player was wrong and made and invalid choice
        stage_3_options() 
        #let the player try again



def stage_3_right():
    #input the range of evil that you want to battle
    #user does not know that his choice affects the creation of the random variable
    #that he has to guess at the end
    choice_evil = input(prompt= "What kind of evil could be out there? (1 weak to 5 high) ").casefold() 
    #if the user picked up the guess at stage two he knows that he can only surely
    #beat middle level evil hence he should max pick number 3 so that he theoretically
    #can win with the three guesses
        
    #when the number is between 1 and 5 continue with the correct loop
    if "1" in choice_evil or  "2" in choice_evil or  "3" in choice_evil or\
    "4" in choice_evil or "5" in choice_evil or  "one" in choice_evil or\
    "two" in choice_evil or  "three" in choice_evil or "four" in choice_evil or\
    "five" in choice_evil:
        
        #Convert the written numbers to numericals so that they can be used later on
        if "one" in choice_evil or "1" in choice_evil:
            choice_evil = 1
        elif "two" in choice_evil or "2" in choice_evil:
            choice_evil = 2
        elif "three" in choice_evil or "3" in choice_evil:
            choice_evil = 3
        elif "four" in choice_evil or "4" in choice_evil:
            choice_evil = 4
        elif "five" in choice_evil or "5" in choice_evil:
            choice_evil = 5
        
        #random number created for the evil that you have to beat
        #affected by the input that user gave above by choice_evil
        #he unknowlingly affects the range of possible numbers random guesses
        evil_random= random.randint(1, choice_evil)
        #print(evil_random)
        #the print above was to check all the options
        
        # player gets three guesses without knowing it
        guesses= 3

        # continue the below processes till all guesses are used
        while guesses > 0:
            
            #user needs to input number and loses one guess with it
            choice_user= input(prompt= "Fight the evil mummies by guessing their number (1-5) ? ").casefold()
            guesses -=1

            if "1" in choice_user or  "2" in choice_user or  "3" in choice_user or\
                "4" in choice_user or  "5" in choice_user or "one" in choice_user or\
                "two" in choice_user or  "three" in choice_user or "four" in choice_user or\
                "five" in choice_user:
                #when number is inputted check if it is the secret random generated number
                
                #creates an integer value for the user inputs so that they can be easier used
                if "one" in choice_user or "1" in choice_user:
                    choice_user = 1
                elif "two" in choice_user or "2" in choice_user:
                    choice_user = 2
                elif "three" in choice_user or "3" in choice_user:
                    choice_user = 3
                elif "four" in choice_user or "4" in choice_user:
                    choice_user = 4
                elif "five" in choice_user or "5" in choice_user:
                    choice_user = 5
                
                
                if choice_user == evil_random:
                    
                    #show user that he guessed correctly
                    print("\nYou guessed correctly!\n")
                    win()
                    break
                    #when number is correct run win sequence
                    #and then break
                else:
                    #when number is not guessed correct back to options
                    
                    if guesses >0:
                        #since guesses are remaining inform that number is incorrect
                        print("Not correct. Guess Again!")
                        continue
                        #and continue the loop
                        

                    elif guesses == 0:
                        #option for when all guesses are used
                        death()
                        break
                        # run death sequence
                        # then break
                    else:
                        print("bug_2")
                        #in case that bugs occur
                        #play again from the options so game can be continued by player
                        stage_3_right()
            else:
                print("bug_1")
                #in case that bugs occur
                #play again from the options so game can be continued by player
                stage_3_right()

                
def stage_3_wrong_1():
    # wrong stage
    #simpel print of the chosen option leading to death sequence
    print(f"""
Outside the door is a bunch of bloodthirsty mummies and you take a torch with 
fire from the side and open the door. Monsters don't like fire and this will surely
work with mummies too. They back away and you get further down the tunnel, when
the fire slowly burns out and they start to attack you. 
         """) 
    death()
    #leading to death sequence 
    
    
def stage_3_wrong_2():
    #print statement displaying the text of this option
    #wrong stage
    print(f"""
Outside the door is a bunch of bloodthirsty mummies and your karate skills will
do the job. You open the door and start to attack the mummies in your way. They go
down and you believe that you will make it, when you realize that they all get up
again. It seems like your karate chop isn't the best. They close in on you and 
you only close your eyes.
         """)
    death()
    #simple print of the chosen option leading to death sequence
       
def win():
    #nice text that displays winning
    #some * lines to make a visible line to differentiate from the game
    print(('*')*80) 
    print(f"""
Congratulations Traveller! You made it! You retrieved the eternity stone from
Hathorn's temple and survived the bloodthirsty mummies! Good job!
 __          ___                       _ 
 \ \        / (_)                     | |
  \ \  /\  / / _ _ __  _ __   ___ _ __| |
   \ \/  \/ / | | '_ \| '_ \ / _ \ '__| |
    \  /\  /  | | | | | | | |  __/ |  |_|
     \/  \/   |_|_| |_|_| |_|\___|_|  (_)                                    
                """)
    #Display of winner sign
    #winner sign taken from the website below
    #https://patorjk.com/software/taag/#p=testall&f=Zodi&t=winner%0A
    #program ends 
    #no chocie to replay for the player since he won
    #if h wants to replay it makes more sense to start the game again
    
def death():
    #sequence to display death
    #* for a nicer look
    print(('*')*80)
    print(f"""   
Traveller, you are dead!
   _____                                            
  / ____|                                           
 | |  __  __ _ _ __ ___   ___    _____   _____ _ __ 
 | | |_ |/ _` | '_ ` _ \ / _ \  / _ \ \ / / _ \ '__|
 | |__| | (_| | | | | | |  __/ | (_) \ V /  __/ |   
  \_____|\__,_|_| |_| |_|\___|  \___/ \_/ \___|_|                                           
                                                    
        """)
    #Display of game over sign
    #game over sign taken from the website below
    #https://patorjk.com/software/taag/#p=testall&f=Zodi&t=game%20over
    death_choices()
    #transition to choice for replaying
    
def death_choices():
    #sequence that let's the user decide if he wants to replay or terminate the game
    replay_choice= input(prompt= "Do you want to play again? (Y/N) \n").casefold()
    #used in an earlier version
    #replay_choice_again=['y', 'yes', 'of course', 'replay']
    #replay_choice_stop= ['stop', 'n', 'no']
    
    #check for the answer of the player to play correct sequence
    if replay_choice == "y" or "yes" in replay_choice or "of course" in replay_choice \
    or "replay" in replay_choice:
        main()
        #start again from the beginning
    elif "stop" in replay_choice or replay_choice == "n" or "no" in replay_choice:
        print("Thanks for playing!")
        pass
        #finishes the game
    else:
        print("Invalid choice, try again.")
        death_choices()
            #in case of unexpected answers give choices again

def main():
    #simple print intro function
    print("Welcome traveller! Are you ready for the adventure of the eternity stone?")
    input(prompt="<Press any key to continue>\n")
    #removd since no global user variables
    #global user_name
    #user_name= input(prompt="What's your name traveller? ").capitalize()
    print("Welcome to the quest traveller!")
    intro()
    #run the into function
#call main to start
main()
# Out:
# Welcome traveller! Are you ready for the adventure of the eternity stone?
# <Press any key to continue>
#
# Welcome to the quest traveller!
#
# No one ever got close to finding the eternity stone, but you are the first one
# who managed to encode your late grandfather's map guiding to Hathor's temple.
#
#
# You follow the map till you end up in front of the huge golden temple entrance
# with lion status on the side.
#
# <Press any key to continue>
#
#
# You walk into the temple and descend the stairs into the darkness. You grab your
# flashlight and continue till the stairs lead into a bigger room .
#
#
# As you step into it, torches light up and reveal three tunnels.
#
# <Press any key to continue>
#
#
# Traveller , which path would you like to choose?
# 1) The left path - with lion paintings
# 2) The middle path - with cobra paintings
# 3) The right path - with falcon paintings
#
# What path are you taking? middle path
#
# ...
